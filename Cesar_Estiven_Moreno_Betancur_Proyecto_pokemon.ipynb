# %% [markdown]
# # Proyecto 1 — Pokémon Data Science Pipeline
#
# **Dataset:** Pokémon (721 observaciones)
#
# ---
#
# ## Objetivo del proyecto
# Construir un **pipeline completo de ciencia de datos** que permita:
#
# 1. Explorar y limpiar datos reales
# 2. Identificar patrones mediante clustering
# 3. Visualizar datos en baja dimensión (PCA)
# 4. Construir un modelo supervisado para predecir el poder ofensivo (`Attack`)
# 5. Publicar el proyecto en GitHub como parte de un portafolio académico

# %% [markdown]
# PREGUNTAS A RESPONDER:
#
# 1. Existen familias naturales de Pokémon según sus stats
# 2. Podemos predecir estadisticas según su tipo

# %% [markdown]
# ## ¿Qué es un pipeline de ciencia de datos?
#
# Un pipeline es una **secuencia ordenada y reproducible de pasos**, típicamente:
#
# 1. Obtención de datos
# 2. Exploración (EDA)
# 3. Limpieza e imputación
# 4. Transformación de variables
# 5. Modelado
# 6. Evaluación
# 7. Comunicación de resultados
#
# Este notebook sigue explícitamente esa estructura.

# %% [markdown]
# ## 1) Obtención de datos desde Kaggle
#
# Kaggle es una plataforma que:
# - aloja datasets reales
# - permite competencias y proyectos
# - es ampliamente usada en portafolios profesionales
#
# Hoy importaremos los datos **directamente desde Kaggle**, sin descargas manuales.

# %% [markdown]
# ### Configuración de Kaggle API en Colab
#
# Pasos:
# 1. Crear una cuenta en Kaggle
# 2. Ir a *Account* → *Create API Token*
# 3. Subir el archivo `kaggle.json` a este entorno
#
# Este archivo contiene credenciales personales.
# **Nunca debe subirse a GitHub.**

# %%
# !pip -q install kaggle

# %%
# !pip -q install ydata-profiling

# %%
import json
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from ydata_profiling import ProfileReport

# %%
kaggle_creds = {
    "username": "token",
    "key": "YOUR TOKEN"
}

os.makedirs("/root/.kaggle", exist_ok=True)

with open("/root/.kaggle/kaggle.json", "w") as f:
    json.dump(kaggle_creds, f)

os.chmod("/root/.kaggle/kaggle.json", 0o600)

# %% [markdown]
# ## 2) Exploración inicial del dataset
#
# Variables principales:
# - Type 1, Type 2: tipos del Pokémon
# - HP, Attack, Defense, Sp. Atk, Sp. Def, Speed: estadísticas base
# - Total: suma de estadísticas (indicador global de poder)
#
# Comenzamos con una exploración básica.

# %% [markdown]
# ## Data access
# This project uses data from Kaggle.
# To reproduce the results, configure Kaggle API credentials
# following Kaggle's official documentation.

# %%
# !kaggle datasets download -d abcsds/pokemon
# Out:
# Dataset URL: https://www.kaggle.com/datasets/abcsds/pokemon
# License(s): CC0-1.0
# pokemon.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !kaggle datasets download -d abcsds/pokemon
# !unzip pokemon.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/abcsds/pokemon
# License(s): CC0-1.0
# pokemon.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  pokemon.zip
# replace Pokemon.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
df = pd.read_csv("Pokemon.csv")
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# EDA Manual

# %%
df.shape
# Out:
# (800, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df.isna().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
tipo1 = df["Type 1"]
tipo2 = df ['Type 2']

# %%
plt.figure(figsize=(8,4))
tipo1.value_counts().plot(kind = 'bar', cmap = 'magma')
plt.title('Frecuencia de los tipos primarios')
plt.xlabel('Cantidad')
plt.ylabel('Tipo')
plt.show()

# %%
plt.figure(figsize=(10,4))
tipo2.value_counts().plot(kind = 'bar', cmap = 'magma')
plt.title('Frecuencia de los tipos primarios')
plt.xlabel('Cantidad')
plt.ylabel('Tipo')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(x = 'Attack',
             data = df,
             bins = 30,
             kde = True,
             color = 'darkcyan')
plt.title('distribución de ataque')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(x = 'Defense',
             data = df,
             bins = 30,
             kde = True,
             color = 'green')
plt.title('distribución de ataque')
plt.show()

# %%
plt.figure(figsize = (6,4))
sns.boxplot( y = 'Type 1',
              x = 'Speed',
              data = df,
              order = tipo1,
              palette = 'Accent')
plt.title('altura de los pokemones según su tipo')
plt.xlabel('altura(dm)')
plt.ylabel('Tipo primario')
plt.show()
# Out:
# /tmp/ipython-input-787168399.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# EDA Online

# %%
profile = ProfileReport(
    df,
    title = "Pokemon Dataset - automated EDA Report",
    explorative = True
)

# %%
#profile

# %%
#profile.to_file("pokemon_eda_report.html")

# %% [markdown]
# ## 3) Limpieza e imputación
#
# La variable `Type 2` tiene valores faltantes porque:
# - muchos Pokémon tienen un solo tipo
#
# Estrategia:
# - imputar los valores faltantes con la categoría `"None"`
#
# Esto preserva la información y evita errores posteriores.

# %%
df['Type 2'] = df['Type 2'].fillna('None')

# %% [markdown]
# ## 4) Clustering no supervisado
#
# Queremos explorar si existen **grupos naturales de Pokémon**
# basados únicamente en sus estadísticas.
#
# Usaremos:
# - KMeans para agrupar
# - PCA para visualizar

# %%
features = ['HP', 'Attack', 'Sp. Atk', 'Sp. Def', 'Speed']
x = df[features].values
type(x)
# Out:
# numpy.ndarray

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
print(x)
print(x_scaled)
# Out:
# [[ 45  49  65  65  45]
#  [ 60  62  80  80  60]
#  [ 80  82 100 100  80]
#  ...
#  [ 80 110 150 130  70]
#  [ 80 160 170 130  80]
#  [ 80 110 130  90  70]]
# [[-0.95062622 -0.92490618 -0.2391303  -0.24818854 -0.80150318]
#  [-0.3628221  -0.5241302   0.21955954  0.29115635 -0.28501525]
#  [ 0.42091674  0.09244823  0.83114599  1.01028289  0.40363531]
#  ...
#  [ 0.42091674  0.95565803  2.36011211  2.08897269  0.05931003]
#  [ 0.42091674  2.49710411  2.97169856  2.08897269  0.40363531]
#  [ 0.42091674  0.95565803  1.74852566  0.65071962  0.05931003]]

# %% [markdown]
# Elbow Method

# %%
inertia = []
K = range(2, 12)

for k in K:
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    km.fit(x_scaled)
    inertia.append(km.inertia_)

plt.plot(K, inertia, marker="o")
plt.xlabel("Número de clusters (k)")
plt.ylabel("Inercia")
plt.title("Elbow method")
plt.show()

# %% [markdown]
# K-means

# %%
kmeans = KMeans(n_clusters=k, random_state = 42, n_init= 10)
clusters = kmeans.fit_predict(x_scaled)

# %% [markdown]
# PCA

# %%
pca = PCA (n_components=2)
x_pca =pca.fit_transform(x_scaled)

# %%
plt.scatter(x_pca[:,0], x_pca[:,1], c=clusters)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Clustering Pokémon visualizado con PCA")
plt.show()

# %%
import plotly.express as px
# 1) Entrenar KMeans con el k elegido (puedes reemplazar best_k por el que quieras)
#k = best_k  # o un número fijo, e.g. 4
kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
labels = kmeans.fit_predict(x_scaled)

# 2) PCA a 3 componentes
pca3 = PCA(n_components=3, random_state=42)
X_3d = pca3.fit_transform(x_scaled)

print("Varianza explicada (3 componentes):", round(pca3.explained_variance_ratio_.sum(), 4))

# 3) DataFrame para visualización (si tienes df con Name/Type, úsalo para hover)
viz = pd.DataFrame({
    "PC1": X_3d[:, 0],
    "PC2": X_3d[:, 1],
    "PC3": X_3d[:, 2],
    "cluster": labels
})

# Si existe df y tiene columnas útiles, agrégalas para hover (opcional)
# Ajusta nombres de columnas si difieren
if "df" in globals():
    for col in ["Name", "Type 1", "Type 2", "Attack", "Defense", "Speed", "HP", "Total"]:
        if col in df.columns:
            viz[col] = df[col].values

hover_cols = [c for c in ["Type 1", "Type 2", "Attack", "Defense", "Speed", "HP", "Total"] if c in viz.columns]

fig = px.scatter_3d(
    viz,
    x="PC1", y="PC2", z="PC3",
    color="cluster",
    hover_name="Name" if "Name" in viz.columns else None,
    hover_data=hover_cols,
    title="Clusterización (KMeans) visualizada con PCA 3D — interactivo"
)

fig.update_traces(marker=dict(size=4))
fig.show()
# Out:
# Varianza explicada (3 componentes): 0.8199
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8b8d2c9c-dfdc-48c8-acb9-4052820eda24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b8d2c9c-dfdc-48c8-acb9-4052820eda24")) {                    Plotly.newPlot(                        "8b8d2c9c-dfdc-48c8-acb9-4052820eda24",                        [{"customdata":[["Grass","Poison",49,49,45,45,318],["Grass","Poison",62,63,60,60,405],["Grass","Poison",82,83,80,80,525],["Grass","Poison",100,123,80,80,625],["Fire","None",52,43,65,39,309],["Fire","None",64,58,80,58,405],["Fire","Flying",84,78,100,78,534],["Fire","Dragon",130,111,100,78,634],["Fire","Flying",104,78,100,78,634],["Water","None",48,65,43,44,314],["Water","None",63,80,58,59,405],["Water","None",83,100,78,79,530],["Water","None",103,120,78,79,630],["Bug","None",30,35,45,45,195],["Bug","None",20,55,30,50,205],["Bug","Flying",45,50,70,60,395],["Bug","Poison",35,30,50,40,195],["Bug","Poison",25,50,35,45,205],["Bug","Poison",90,40,75,65,395],["Bug","Poison",150,40,145,65,495],["Normal","Flying",45,40,56,40,251],["Normal","Flying",60,55,71,63,349],["Normal","Flying",80,75,101,83,479],["Normal","Flying",80,80,121,83,579],["Normal","None",56,35,72,30,253],["Normal","None",81,60,97,55,413],["Normal","Flying",60,30,70,40,262],["Normal","Flying",90,65,100,65,442],["Poison","None",60,44,55,35,288],["Poison","None",85,69,80,60,438],["Electric","None",55,40,90,35,320],["Electric","None",90,55,110,60,485],["Ground","None",75,85,40,50,300],["Ground","None",100,110,65,75,450],["Poison","None",47,52,41,55,275],["Poison","None",62,67,56,70,365],["Poison","Ground",92,87,76,90,505],["Poison","None",57,40,50,46,273],["Poison","None",72,57,65,61,365],["Poison","Ground",102,77,85,81,505],["Fairy","None",45,48,35,70,323],["Fairy","None",70,73,60,95,483],["Fire","None",41,40,65,38,299],["Fire","None",76,75,100,73,505],["Normal","Fairy",45,20,20,115,270],["Normal","Fairy",70,45,45,140,435],["Poison","Flying",45,35,55,40,245],["Poison","Flying",80,70,90,75,455],["Grass","Poison",50,55,30,45,320],["Grass","Poison",65,70,40,60,395],["Grass","Poison",80,85,50,75,490],["Bug","Grass",70,55,25,35,285],["Bug","Grass",95,80,30,60,405],["Bug","Poison",55,50,45,60,305],["Bug","Poison",65,60,90,70,450],["Ground","None",55,25,95,10,265],["Ground","None",80,50,120,35,405],["Normal","None",45,35,90,40,290],["Normal","None",70,60,115,65,440],["Water","None",52,48,55,50,320],["Water","None",82,78,85,80,500],["Fighting","None",80,35,70,40,305],["Fighting","None",105,60,95,65,455],["Fire","None",70,45,60,55,350],["Fire","None",110,80,95,90,555],["Water","None",50,40,90,40,300],["Water","None",65,65,90,65,385],["Water","Fighting",95,95,70,90,510],["Psychic","None",20,15,90,25,310],["Psychic","None",35,30,105,40,400],["Psychic","None",50,45,120,55,500],["Psychic","None",50,65,150,55,590],["Fighting","None",80,50,35,70,305],["Fighting","None",100,70,45,80,405],["Fighting","None",130,80,55,90,505],["Grass","Poison",75,35,40,50,300],["Grass","Poison",90,50,55,65,390],["Grass","Poison",105,65,70,80,490],["Water","Poison",40,35,70,40,335],["Water","Poison",70,65,100,80,515],["Rock","Ground",80,100,20,40,300],["Rock","Ground",95,115,35,55,390],["Rock","Ground",120,130,45,80,495],["Fire","None",85,55,90,50,410],["Fire","None",100,70,105,65,500],["Water","Psychic",65,65,15,90,315],["Water","Psychic",75,110,30,95,490],["Water","Psychic",75,180,30,95,590],["Electric","Steel",35,70,45,25,325],["Electric","Steel",60,95,70,50,465],["Normal","Flying",65,55,60,52,352],["Normal","Flying",85,45,75,35,310],["Normal","Flying",110,70,100,60,460],["Water","None",45,55,45,65,325],["Water","Ice",70,80,70,90,475],["Poison","None",80,50,25,80,325],["Poison","None",105,75,50,105,500],["Water","None",65,100,40,30,305],["Water","Ice",9 ...

# %% [markdown]
# ## 5) Aprendizaje supervisado
#
# Ahora construiremos un modelo para **predecir el Attack**
# usando:
# - estadísticas base
# - tipo principal (Type 1)
#
# Esto requiere:
# - codificar variables categóricas
# - separar train/test
# - evaluar desempeño

# %%
cat = df[['Type 1']]
num = df[['HP', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]

# %%
encoder = OneHotEncoder(sparse_output= False)
X_cat = encoder.fit_transform(cat)

# %%
X_all = np.hstack((num.values, X_cat))

# %%
y = df['Attack'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print("R2:", r2)
print("RMSE:", mse)
# Out:
# R2: 0.5037366278757756
# RMSE: 536.9847089855009

# %% [markdown]
# Modelo 2: Solo variables correlación

# %%
X2 = df[['HP', 'Defense']].values
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y, test_size=0.2, random_state=42)

# %%
model2 = LinearRegression()
model2.fit(X2_train, y2_train)
y2_pred = model2.predict(X2_test)

# %%
r2 = r2_score(y2_test, y2_pred)
mse = mean_squared_error(y2_test, y2_pred)
print("R2:", r2)
print("RMSE:", mse)
# Out:
# R2: 0.28557643985523706
# RMSE: 773.0462272373586

# %% [markdown]
# Modelo 3: Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rf= RandomForestRegressor(
    n_estimators=500,
    random_state=42,
    criterion='absolute_error',
    min_samples_leaf=2,
    n_jobs= -1
)

# %%
rf.fit(X2_train, y2_train)
yrf_pred = rf.predict(X2_test)

# %%
r2= r2_score(y2_test, yrf_pred)
mse = mean_squared_error(y_test, yrf_pred)
print("R2:", r2)
print("RMSE:", mse)
# Out:
# R2: 0.2905901937843942
# RMSE: 767.6210652249999

# %% [markdown]
# ## 6) Publicación del proyecto en GitHub
#
# GitHub es:
# - un repositorio de código
# - una vitrina profesional
# - un historial de tu trabajo
#
# Un buen proyecto debe incluir:
# - notebooks claros
# - estructura ordenada
# - un README explicativo

# %% [markdown]
# ### Estructura recomendada
#
# pokemon-project/
# ├── data/        (opcional, si el dataset es liviano)
# ├── notebooks/
# │   └── pokemon_analysis.ipynb
# ├── figures/
# ├── README.md

# %% [markdown]
# # Pokémon Data Science Project
#
# ## Objective
# Analyze Pokémon statistics to identify patterns and predict offensive power.
#
# ## Dataset
# Source: Kaggle — Pokémon Dataset (800 Pokémon)
#
# ## Methods
# - EDA
# - Missing value imputation
# - KMeans clustering + PCA
# - Linear Regression
# - Random Forest
#
# ## Results
# - Identified clusters of similar Pokémon
# - Built a regression model to predict Attack (It did not work)
#
# ## Tools
# Python, Pandas, NumPy, Scikit-learn
#
# ## Author
# Cesar Estiven Moreno Betancur
